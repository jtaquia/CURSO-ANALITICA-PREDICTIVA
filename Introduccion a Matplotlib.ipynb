# %%
import imageio
import matplotlib.pyplot as plt 
import os
import scipy.ndimage as ndi 
import numpy as np

# %%
os.chdir("C://Users//Intel//Documents//PROYECTOS SECTOR SALUD//BIO_MEDICAL//DATA INSN")

# %%
#im = imageio.imread('edad osea2.bmp').astype('float64')

# %%
im = imageio.imread('edad osea2.bmp')

# %%
im.dtype
# Out:
# dtype('float64')

# %%
im.size
im.shape
# Out:
# (1320, 904, 3)

# %%
plt.imshow(im,cmap='gray') 
plt.axis('off') 
plt.show()

# %%
# APLICAMOS FILTROS A LA IMAGEN
mask1 = im>40
mask1.shape
im_bone	=np.where(mask1,im,	0)

# %%
plt.imshow(im_bone,cmap='gray') 
plt.axis('on') 
plt.show()

# %%
hist = ndi.histogram(im,min=0,max=255,bins=256) 
hist.shape
plt.plot(hist)
plt.show()

# %%
cdf	= hist.cumsum()/hist.sum() 
#cdf.shape

# %%
#PLOTEO DE HISTOGRAMAS
fig,axes = plt.subplots(2, 1,sharex=True) 
axes[0].plot(hist,label='Histograma')
axes[1].plot(cdf, label = 'Dist. Acum.')
#format_and_render_plot()
plt.show()
